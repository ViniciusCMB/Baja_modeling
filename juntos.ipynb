# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
RPM_Motora1 = [1420,
               1580,
               1521,
               2580,
               2542,
               2580,
               3677,
               3720,
               3723]

RPM_Movida1 = [298,
               329,
               326,
               3228,
               3050,
               3081,
               4549,
               4576,
               4592]

print('Caso 1 - Mola nova sem carga')
relacao1 = [RPM_Motora1[i]/RPM_Movida1[i] for i in range(len(RPM_Motora1))]
Rmax1 = (relacao1[0] + relacao1[1] + relacao1[2])/3
RPM_Rmax1 = (RPM_Motora1[0] + RPM_Motora1[1] + RPM_Motora1[2])/3
RPM_2Rmax1 = (RPM_Movida1[0] + RPM_Movida1[1] + RPM_Movida1[2])/3
print(f'Redução máxima: {Rmax1:.2f} a {RPM_Rmax1:.0f} RPM ({RPM_2Rmax1:.0f} RPM)')

Rmin1 = (relacao1[3] + relacao1[4] + relacao1[5])/3
RPM_Rmin1 = (RPM_Motora1[3] + RPM_Motora1[4] + RPM_Motora1[5])/3
RPM_2Rmin1 = (RPM_Movida1[3] + RPM_Movida1[4] + RPM_Movida1[5])/3
print(f'Redução mínima: {Rmin1:.2f} a {RPM_Rmin1:.0f} RPM ({RPM_2Rmin1:.0f} RPM)')

print(f'Faixa de trabalho CVT: {RPM_Rmax1:.0f} a {RPM_Rmin1:.0f} RPM')

RPM_F1 = (RPM_Motora1[-1]+RPM_Motora1[-2]+RPM_Motora1[-3])/3
RPM_2F1 = (RPM_Movida1[-1]+RPM_Movida1[-2]+RPM_Movida1[-3])/3
print(f'RPM final: {RPM_F1:.0f} ({RPM_2F1:.0f})')

R_F1 = (relacao1[-1] + relacao1[-2] + relacao1[-3])/3
print(f'Relação à {RPM_F1:.0f} RPM: {R_F1:.2f}')

velocidade1 = [((0.377*0.25*RPM_Motora1[i])/(7.2*relacao1[i]))
               for i in range(len(RPM_Motora1))]
Vmax1 = (velocidade1[-1]+velocidade1[-2]+velocidade1[-3])/3

print(f'Velocidade máxima: {Vmax1:.2f} Km/h')

torque_Motor = [
    24.9,  # 2k
    26.5,  # 2,5k
    26,  # 3k
    22.5  # 3,6
]

f2k1 = ((2.9 * 7.2)*torque_Motor[0])/0.25
f25k1 = ((Rmin1 * 7.2)*torque_Motor[1])/0.25
f3k1 = ((Rmin1 * 7.2)*torque_Motor[2])/0.25
f36k1 = ((Rmin1 * 7.2)*torque_Motor[3])/0.25

print(f'Força na roda em 2000 RPM: {f2k1:.0f} N')
print(f'Força na roda em 2500 RPM: {f25k1:.0f} N')
print(f'Força na roda em 3000 RPM: {f3k1:.0f} N')
print(f'Força na roda em 3600 RPM: {f36k1:.0f} N')

print('Temperatura da correia no fim do teste: 54 ºC')

print('---------------------------------')

RPM_Motora2 = [1584,
               1571,
               1514,
               2487,
               2401,
               2454,
               3727,
               3743,
               3729]

RPM_Movida2 = [349,
               354,
               310,
               3026,
               2969,
               3074,
               4632,
               4659,
               4640]

print('Caso 2 - Mola velha sem carga')
relacao2 = [RPM_Motora2[i]/RPM_Movida2[i] for i in range(len(RPM_Motora2))]
Rmax2 = (relacao2[0] + relacao2[1] + relacao2[2])/3
RPM_Rmax2 = (RPM_Motora2[0] + RPM_Motora2[1] + RPM_Motora2[2])/3
RPM_2Rmax2 = (RPM_Movida2[0]+RPM_Movida2[1]+RPM_Movida2[2])/3
print(f'Redução máxima: {Rmax2:.2f} a {RPM_Rmax2:.0f} RPM ({RPM_2Rmax2:.0f} RPM)')

Rmin2 = (relacao2[3] + relacao2[4] + relacao2[5])/3
RPM_Rmin2 = (RPM_Motora2[3] + RPM_Motora2[4] + RPM_Motora2[5])/3
RPM_2Rmin2 = (RPM_Movida2[3]+RPM_Movida2[4]+RPM_Movida2[5])/3
print(f'Redução mínima: {Rmin2:.2f} a {RPM_Rmin2:.0f} RPM ({RPM_2Rmin2:.0f} RPM)')

print(f'Faixa de trabalho CVT: {RPM_Rmax2:.0f} a {RPM_Rmin2:.0f} RPM')

RPM_F2 = (RPM_Motora2[-1]+RPM_Motora2[-2]+RPM_Motora2[-3])/3
RPM_2F2 = (RPM_Movida2[-1]+RPM_Movida2[-2]+RPM_Movida2[-3])/3
print(f'RPM final: {RPM_F2:.0f} ({RPM_2F2:.0f})')

R_F2 = (relacao2[-1] + relacao2[-2] + relacao2[-3])/3
print(f'Relação à {RPM_F2:.0f} RPM: {R_F2:.2f}')

velocidade2 = [((0.377*0.25*RPM_Motora2[i])/(7.2*relacao2[i]))
               for i in range(len(RPM_Motora2))]
Vmax2 = (velocidade2[-1]+velocidade2[-2]+velocidade2[-3])/3

print(f'Velocidade máxima: {Vmax2:.2f} Km/h')

f2k2 = ((2.7 * 7.2)*torque_Motor[0])/0.25
f25k2 = ((Rmin2 * 7.2)*torque_Motor[1])/0.25
f3k2 = ((Rmin2 * 7.2)*torque_Motor[2])/0.25
f36k2 = ((Rmin2 * 7.2)*torque_Motor[3])/0.25

print(f'Força na roda em 2000 RPM: {f2k2:.0f} N')
print(f'Força na roda em 2500 RPM: {f25k2:.0f} N')
print(f'Força na roda em 3000 RPM: {f3k2:.0f} N')
print(f'Força na roda em 3600 RPM: {f36k2:.0f} N')

print('Temperatura da correia no fim do teste: 71 ºC')

print('---------------------------------')

RPM_Motora3 = [1640,
               1638,
               1590,
               2840,
               3106,
               2737,
               3683,
               3700,
               3696]

RPM_Movida3 = [416,
               373,
               338,
               3310,
               3714,
               3272,
               4285,
               4483,
               4476]

print('Caso 3 - Mola velha com carga')
relacao3 = [RPM_Motora3[i]/RPM_Movida3[i] for i in range(len(RPM_Motora3))]
Rmax3 = (relacao3[0] + relacao3[1] + relacao3[2])/3
RPM_Rmax3 = (RPM_Motora3[0] + RPM_Motora3[1] + RPM_Motora3[2])/3
RPM_2Rmax3 = (RPM_Movida3[0]+RPM_Movida3[1]+RPM_Movida3[2])/3
print(f'Redução máxima: {Rmax3:.2f} a {RPM_Rmax3:.0f} RPM ({RPM_2Rmax3:.0f} RPM)')

Rmin3 = (relacao3[3] + relacao3[4] + relacao3[5])/3
RPM_Rmin3 = (RPM_Motora3[3] + RPM_Motora3[4] + RPM_Motora3[5])/3
RPM_2Rmin3 = (RPM_Movida3[3]+RPM_Movida3[4]+RPM_Movida3[5])/3
print(f'Redução mínima: {Rmin3:.2f} a {RPM_Rmin3:.0f} RPM ({RPM_2Rmin3:.0f} RPM)')


print(f'Faixa de trabalho CVT: {RPM_Rmax3:.0f} a {RPM_Rmin3:.0f} RPM')

RPM_F3 = (RPM_Motora3[-1]+RPM_Motora3[-2]+RPM_Motora3[-3])/3
RPM_2F3 = (RPM_Movida3[-1]+RPM_Movida3[-2]+RPM_Movida3[-3])/3
print(f'RPM final: {RPM_F3:.0f} ({RPM_2F3:.0f})')

R_F3 = (relacao3[-1] + relacao3[-2] + relacao3[-3])/3
print(f'Relação à {RPM_F3:.0f} RPM: {R_F3:.2f}')

velocidade3 = [((0.377*0.25*RPM_Motora3[i])/(7.2*relacao3[i]))
               for i in range(len(RPM_Motora3))]
Vmax3 = (velocidade3[-1]+velocidade3[-2]+velocidade3[-3])/3

print(f'Velocidade máxima: {Vmax3:.2f} Km/h')

f2k3 = ((3.3 * 7.2)*torque_Motor[0])/0.25
f25k3 = ((Rmin3 * 7.2)*torque_Motor[1])/0.25
f3k3 = ((Rmin3 * 7.2)*torque_Motor[2])/0.25
f36k3 = ((Rmin3 * 7.2)*torque_Motor[3])/0.25

print(f'Força na roda em 2000 RPM: {f2k3:.0f} N')
print(f'Força na roda em 2500 RPM: {f25k3:.0f} N')
print(f'Força na roda em 3000 RPM: {f3k3:.0f} N')
print(f'Força na roda em 3600 RPM: {f36k3:.0f} N')

print('Temperatura da correia no fim do teste: 56 ºC')
# Out:
# Caso 1 - Mola nova sem carga
# Redução máxima: 4.74 a 1507 RPM (318 RPM)
# Redução mínima: 0.82 a 2567 RPM (3120 RPM)
# Faixa de trabalho CVT: 1507 a 2567 RPM
# RPM final: 3707 (4572)
# Relação à 3707 RPM: 0.81
# Velocidade máxima: 59.85 Km/h
# Força na roda em 2000 RPM: 2080 N
# Força na roda em 2500 RPM: 628 N
# Força na roda em 3000 RPM: 617 N
# Força na roda em 3600 RPM: 534 N
# Temperatura da correia no fim do teste: 54 ºC
# ---------------------------------
# Caso 2 - Mola velha sem carga
# Redução máxima: 4.62 a 1556 RPM (338 RPM)
# Redução mínima: 0.81 a 2447 RPM (3023 RPM)
# Faixa de trabalho CVT: 1556 a 2447 RPM
# RPM final: 3733 (4644)
# Relação à 3733 RPM: 0.80
# Velocidade máxima: 60.79 Km/h
# Força na roda em 2000 RPM: 1936 N
# Força na roda em 2500 RPM: 618 N
# Força na roda em 3000 RPM: 606 N
# Força na roda em 3600 RPM: 525 N
# Temperatura da correia no fim do teste: 71 ºC
# ---------------------------------
# Caso 3 - Mola velha com carga
# ...

# %%
RPM_Motora_F1 = [1200, RPM_Rmax1, RPM_Rmin1, 3600]
Relacao_F1 = [Rmax1, Rmax1, Rmin1, Rmin1]

plt.plot(RPM_Motora_F1, Relacao_F1, 'o-', label='Opção 1')

RPM_Motora_F2 = [1200, RPM_Rmax2, RPM_Rmin2, 3600]
Relacao_F2 = [Rmax2, Rmax2, Rmin2, Rmin2]

plt.plot(RPM_Motora_F2, Relacao_F2, 'o-', label='Opção 2')

RPM_Motora_F3 = [1200, RPM_Rmax3, RPM_Rmin3, 3600]
Relacao_F3 = [Rmax3, Rmax3, Rmin3, Rmin3]

plt.plot(RPM_Motora_F3, Relacao_F3, 'o-', label='Opção 3')

plt.grid()
plt.legend()
plt.xlabel('RPM Motor')
plt.ylabel('Relação de redução')
plt.title('Relação de redução x RPM Motor (Sobrepostas)')
plt.show()

# %%
RPM = np.linspace(0, 3600, 101)


def rela(RPM):
    if RPM <= RPM_Rmax1:
        return Rmax1
    else:
        if RPM <= RPM_Rmin1:
            a = (Rmax1-Rmin1)/(RPM_Rmax1-RPM_Rmin1)
            b = Rmax1-(RPM_Rmax1*a)
            return (a*RPM)+b
        else:
            return Rmin1


V_F1 = [((0.377*0.25*RPM_Motora_F1[i])/(7.2*Relacao_F1[i]))
        for i in range(len(RPM_Motora_F1))]

V1 = [((0.377*0.25*RPM[i])/(7.2*rela(RPM[i])))
      for i in range(len(RPM))]

V_Rel_Max1 = [((0.377*0.25*RPM[i])/(7.2*Rmax1))
              for i in range(len(RPM))]

V_Rel_Min1 = [((0.377*0.25*RPM[i])/(7.2*Rmin1))
              for i in range(len(RPM))]

plt.plot(V_Rel_Max1, RPM, 'k--')
plt.plot(V_Rel_Min1, RPM, 'k--')
plt.plot(V1, RPM, '-', label='Opção 1')


def rela2(RPM):
    if RPM <= RPM_Rmax2:
        return Rmax2
    else:
        if RPM <= RPM_Rmin2:
            a = (Rmax2-Rmin2)/(RPM_Rmax2-RPM_Rmin2)
            b = Rmax2-(RPM_Rmax2*a)
            return (a*RPM)+b
        else:
            return Rmin2


V_F2 = [((0.377*0.25*RPM_Motora_F2[i])/(7.2*Relacao_F2[i]))
        for i in range(len(RPM_Motora_F2))]

V2 = [((0.377*0.25*RPM[i])/(7.2*rela2(RPM[i])))
      for i in range(len(RPM))]

V_Rel_Max2 = [((0.377*0.25*RPM[i])/(7.2*Rmax2))
              for i in range(len(RPM))]

V_Rel_Min2 = [((0.377*0.25*RPM[i])/(7.2*Rmin2))
              for i in range(len(RPM))]

plt.plot(V_Rel_Max2, RPM, 'k--')
plt.plot(V_Rel_Min2, RPM, 'k--')
plt.plot(V2, RPM, '-', label='Opção 2')


def rela3(RPM):
    if RPM <= RPM_Rmax3:
        return Rmax3
    else:
        if RPM <= RPM_Rmin3:
            a = (Rmax3-Rmin3)/(RPM_Rmax3-RPM_Rmin3)
            b = Rmax3-(RPM_Rmax3*a)
            return (a*RPM)+b
        else:
            return Rmin3


V_F3 = [((0.377*0.25*RPM_Motora_F3[i])/(7.2*Relacao_F3[i]))
        for i in range(len(RPM_Motora_F3))]

V3 = [((0.377*0.25*RPM[i])/(7.2*rela3(RPM[i])))
      for i in range(len(RPM))]

V_Rel_Max3 = [((0.377*0.25*RPM[i])/(7.2*Rmax3))
              for i in range(len(RPM))]

V_Rel_Min3 = [((0.377*0.25*RPM[i])/(7.2*Rmin3))
              for i in range(len(RPM))]

RPM_MIN = [2000 for i in range(len(V1))]
RPM_MAX = [3600 for i in range(len(V1))]
RPM_TMAX = [2500 for i in range(len(V1))]
RPM_PMAX = [3600 for i in range(len(V1))]
plt.plot(V_Rel_Max3, RPM, 'k--')
plt.plot(V_Rel_Min3, RPM, 'k--')
plt.plot(V3, RPM, '-', label='Opção 3')

plt.plot(V1, RPM_TMAX, 'r-.', label='Rotação de Torque Máximo')
plt.plot(V1, RPM_PMAX, 'b-.', label='Rotação de Potência Máxima')

plt.legend()
plt.grid()
plt.xlabel('Velocidade (Km/h)')
plt.ylabel('RPM Motor')
plt.title('RPM Motor x Velocidade (Curvas CVT Sobrepostas)')
plt.show()
